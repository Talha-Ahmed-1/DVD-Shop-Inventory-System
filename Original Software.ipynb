# %%
def inventory():
    file=open("pass.txt","r+")
    ask="y"
    ask=ask.lower()
    while ask=="y":
        name=input("Enter Name:\n")
        name=name.replace(" ","?")
        name1=name.lower()
        clear()
        for i in file:
            i=i.split()
            while name1 in i:
                print("Name already present enter another name otherwise go to edit mood by write (edit):")
                name=input("Enter Name:\n")
                name=name.replace(" ","?")
                name1=name.lower()
                clear()
        if name1=="edit":
            edit()
        else:
            typee=(input("Enter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
            typee=str(typee)
            while typee!="1" and typee!="2" and typee!="3":
                print("Please give valid instructions.")
                typee=(input("Enter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
                typee=str(typee)
            quantity=(input("Enter Quantity: \n"))
            quantity=str(quantity)
            price=(input("Price: \n"))
            price=str(price)
            clear()
            print("Updated.....")
            ask=input("Do you want to edit more please answer in (y or n): \n")
            clear()
            ask=ask.lower()
            update=(typee+" "+name1+" "+quantity+" "+price+"\n")
            file=open("pass.txt","a")
            file.write(update)
    file.close()
    clear()
    main()
def inventorycheck():
    count=1
    chk=(input("For Check all info about a DVD press 1:\nFor Type press 2:\nFor Quantity press 3:\nFor Price press 4:\nFor Check Whole Inventory press 5:\n"))
    clear()
    while chk!="1" and chk!="2" and chk!="3" and chk!="4" and chk!="5":
        print("Please give valid instructions.")
        chk=(input("For Check all info about a DVD press 1:\nFor Type press 2:\nFor Quantity press 3:\nFor Price press 4:\nFor Check Whole Inventory press 5:\n"))
        clear()
    if chk=="1":
        while count==1:
            name=input("Enter DVD Name: ")
            clear()
            file1 = open('pass.txt','r')
            name=name.replace(" ","?")
            name1=name.lower()
            for i in file1:
                if name1=="main":
                    clear()
                    main()
                if name1 in i:
                    count = count -1
                    i1=i.split()
                    types,names,quantities,prices=i1[0],i1[1],i1[2],i1[3]
                    names=names.replace("?"," ")
                    names=names.title()
                    if types=="1":
                        types="Games"
                    if types=="2":
                        types="Softwares"
                    if types=="3":
                        types="Movies"
                    print("Name                Type            Quantity        Price")
                    print("|{0:20}|{1:15}|{2:15}|{3:5}".format(names,types,quantities,prices))
            if count==1:
                print("Name isn't present in inventory for goto main page type (main).")
            file1.close()
    if chk=="2":
        while count==1:
            name=input("Enter DVD Name: ")
            file1 = open('pass.txt','r')
            name=name.replace(" ","?")
            name1=name.lower()
            clear()
            for i in file1:
                if name1=="main":
                    clear()
                    main()
                if name1 in i:
                    count = count -1
                    i1=i.split()
                    if i1[0]=="1":
                        print("Type: Game")
                    if i1[0]=="2":
                        print("Type: Software")
                    if i1[0]=="3":
                        print("Type: Movie")
            if count==1:
                print("Name isn't present in inventory for goto main page type (main).")
            file1.close()
    if chk=="3":
        while count==1:
            name=input("Enter DVD Name: ")
            file1 = open('pass.txt','r')
            name=name.replace(" ","?")
            name1=name.lower()
            clear()
            for i in file1:
                if name1=="main":
                    clear()
                    main()
                if name1 in i:
                    count = count -1
                    i1=i.split()
                    print("Quantity: ",i1[2])
            if count==1:
                print("Name isn't present in inventory for goto main page type (main).")
            file1.close()
    if chk=="4":
        while count==1:
            name=input("Enter DVD Name: ")
            file1 = open('pass.txt','r')
            name=name.replace(" ","?")
            name1=name.lower()
            clear()
            for i in file1:
                if name1=="main":
                    clear()
                    main()
                if name1 in i:
                    count = count -1
                    i1=i.split()
                    print("Price: ",i1[3])
            if count==1:
                print("Name isn't present in inventory for goto main page type (main).")
            file1.close()
    if chk=="5":
        files=open("pass.txt","r")
        a=files.readlines()
        s=0
        for k in a:
            k=k.split()
            k[2]=int(k[2])
            s+=k[2]
        print("Total DVD's present in stock: ",s)
        print("Total DVD's of different names: ",len(a))
        files.close()
        file1=open("pass.txt","r") 
        print("Name                 Type            Quantity        Price")
        for i in file1:
            i1=i.split()
            types,names,quantities,prices=i1[0],i1[1],i1[2],i1[3]
            names=names.replace("?"," ")
            if types=="1":
                types="Games"
            if types=="2":
                types="Softwares"
            if types=="3":
                types="Movies"
            print("|{0:20}|{1:15}|{2:15}|{3:5}".format(names,types,quantities,prices))
        file1.close()
    do=input("Do you want to check more items press (y) else (n)")
    do=do.lower()
    clear()
    if do=="y":
        inventorycheck()
    else:
        main()
def edit():
    count=1
    while count == 1:
        name=input("Enter DVD Name: ")
        file1 = open('pass.txt','r')
        name=name.replace(" ","?")
        name1=name.lower()
        clear()
        for i in file1:
            if name1=="main":
                clear()
                main()
            if name1 in i:
                count-=1
        if count==1:
            print("Name isn't present in inventory for goto main page type (main).")
        file1.close()
    file2=open("pass.txt","r")
    what=(input("For change whole info about a DVD press 1:\nFor change Type press 2:\nFor change Quantity press 3:\nFor change Price press 4:\nFor change Name press 5:\n"))
    clear()
    while what!="1" and what!="2" and what!="3" and what!="4" and what!="5":
        what=(input("For change whole info about a DVD press 1:\nFor change Type press 2:\nFor change Quantity press 3:\nFor change Price press 4:\nFor change Name press 5:\n"))
        clear()
    if what=="1":
        a=file2.readlines()
        for i in a:
            x=a.index(i)
            i=i.split()
            if name1 == i[1]:
                i10=(input("...:For Replace:...\nEnter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
                i10=str(i10)
                clear()
                while i10!="1" and i10!="2" and i10!="3":
                    print("Please give valid instructions.")
                    i10=(input("...:For Replace:...\nEnter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
                    i10=str(i10)
                    clear()
                i11=input("Enter Name:\n")
                i11=i11.replace(" ","?")
                i11=i11.lower()
                clear()
                file5=open("pass.txt","r")
                for i5 in file5:
                    i5=i5.split()
                    while i11 in i5:
                        print("Name already present enter another name otherwise go to edit mood by write (edit):")
                        i11=input("Enter Name:\n")
                        i11=i11.replace(" ","?")
                        i11=i11.lower()
                        clear()
                if name1=="edit":
                    edit()                
                file5.close()
                i12=(input("Enter Quantity: \n"))
                i12=str(i12)
                clear()
                i13=(input("Price: \n"))
                i13=str(i13)
                clear()
                print("Edited.....")
                a[x]=i10+" "+i11+" "+i12+" "+i13+"\n"
                file3=open("pass.txt","w")
                file3.writelines(a)
                file3.close()
    if what=="2":
        a=file2.readlines()
        for i in a:
            x=a.index(i)
            i=i.split()
            if name1 == i[1]:
                i10=(input("...:For Replace:...\nEnter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
                i10=str(i10)
                clear()
                while i10!="1" and i10!="2" and i10!="3":
                    print("Please give valid instructions.")
                    i10=(input("...:For Replace:...\nEnter 1 for Game\nEnter 2 for Software\nEnter 3 for Movie\n"))
                    i10=str(i10)
                    clear()
                a[x]=i10+" "+i[1]+" "+i[2]+" "+i[3]+"\n"
                clear()
                print("Edited.....")
                file3=open("pass.txt","w")
                file3.writelines(a)
                file3.close()
    if what=="3":
        a=file2.readlines()
        for i in a:
            x=a.index(i)
            i=i.split()
            if name1 == i[1]:
                i12=(input("Enter Quantity: \n"))
                i12=str(i12)
                a[x]=i[0]+" "+i[1]+" "+i12+" "+i[3]+"\n"
                clear()
                print("Edited.....")
                file3=open("pass.txt","w")
                file3.writelines(a)
                file3.close()
    if what=="4":
        a=file2.readlines()
        for i in a:
            x=a.index(i)
            i=i.split()
            if name1 == i[1]:
                i13=(input("Price: \n"))
                i13=str(i13)
                a[x]=i[0]+" "+i[1]+" "+i[2]+" "+i13+"\n"
                clear()
                print("Edited.....")
                file3=open("pass.txt","w")
                file3.writelines(a)
                file3.close()
    if what=="5":
        a=file2.readlines()
        for i in a:
            x=a.index(i)
            i=i.split()
            if name1 == i[1]:
                i11=input("Enter Name:\n")
                i11=i11.replace(" ","?")
                i11=i11.lower()
                clear()
                file5=open("pass.txt","r")
                for i5 in file5:
                    i5=i5.split()
                    while i11 in i5:
                        print("Name already present enter another name otherwise go to edit mood by write (edit):")
                        i11=input("Enter Name:\n")
                        i11=i11.replace(" ","?")
                        i11=i11.lower()
                        clear()
                if name1=="edit":
                    edit()                
                file5.close()
                a[x]=i[0]+" "+i11+" "+i[2]+" "+i[3]+"\n"
                clear()
                print("Edited.....")
                file3=open("pass.txt","w")
                file3.writelines(a)
                file3.close()
    main()
def delete():
    count=1
    while count==1:
        name=input("Enter DVD Name: ")
        file1 = open('pass.txt','r')
        name=name.replace(" ","?")
        name1=name.lower()
        clear()
        for i in file1:
            if name1=="main":
                main()
            if name1 in i:
                count-=1
        if count==1:
            print("Name isn't present in inventory for goto main page type (main).")
        file1.close()
    file4=open("pass.txt","r+")
    a=file4.readlines()
    for i in a:
        x=a.index(i)
        i=i.split()
        if name1 == i[1]:
            a.remove(a[x])
            file5=open("pass.txt","w")
            file5.writelines(a)
            file5.close()
    print("Deleted.....")
    do=input("Do you want to delete more items press (y) else (n)")
    do=do.lower()
    clear()
    if do=="y":
        inventorycheck()
    else:
        main()
    file4.close()
def sale():
    import time
    count=1
    while count==1:
        name=input("Enter DVD Name: ")
        file1 = open('pass.txt','r')
        name=name.replace(" ","?")
        name1=name.lower()
        clear()
        for i in file1:
            if name1=="main":
                main()
            if name1 in i:
                count = count -1
                i1=i.split()
                print("Quantity: ",i1[2])
                print("Price: ",i1[3])
        if count==1:
            print("Name isn't present in inventory for goto main page type (main).")
        file1.close()
    i1[2]=int(i1[2])
    if i1[2]>0:
        much=eval(input("How much DVD do you want:"))
        clear()
        if i1[2]>=much:
            file2=open("pass.txt","r")
            a=file2.readlines()
            for i in a:
                x=a.index(i)
                i=i.split()
                if name1 == i[1]:
                    i12=int(i[2])
                    i12-=much
                    i12=str(i12)
                    a[x]=i[0]+" "+i[1]+" "+i12+" "+i[3]+"\n"
                    your=int(i[3])*much
                    print("Total Price=",your)
                    pay=eval(input("Please pay cash: "))
                    clear()
                    while pay<your:
                        pays=eval(input("Please pay more cash: "))
                        pay+=pays
                        clear()
                    returned=0
                    if pay>your:
                        returned=pay-your
                    print("Purchased.")
                    print("Remaining stock is: ",i12)
                    file3=open("pass.txt","w")
                    file3.writelines(a)
                    file3.close()
                    f=open("sales.txt","a")
                    times=time.strftime("%d/%m",time.localtime())
                    times=str(times)
                    f.write(times+" "+name1+" "+str(much)+" "+str(your)+"\n")
                    f.close()
                    name1=name1.title()
                    if returned>0:
                        print("\nReciept:")
                        print("Name: {0}\nQuantity: {4}\nTotal: {2}\nCash: {1}\nReturned: {3}".format(name1,pay,your,returned,much))
                    else:
                        print("Reciept:")
                        print("Name: {0}\nQuantity: {4}\nTotal: {2}\nCash: {1}\nReturned: {3}".format(name1,pay,your,returned,much))
            file2.close()
        else:
            print("Out of Stock...")
            sale()
    else:
        print("Out of stock...")
        sale()
    main()
def checksale():
    count=1
    chk=(input("For Check all info about a DVD sale by name press 1:\nFor Check all info about a DVD sale by date press 2:\nFor check total sale uptill now press 3:\n"))
    clear()
    while chk!="1" and chk!="2" and chk!="3":
        print("Please give valid instructions.")
        chk=(input("For Check all info about a DVD sale by name press 1:\nFor Check all info about a DVD sale by date press 2:\nFor check total sale uptill now press 3:\n"))
        clear()
    if chk=="1":
        while count==1:
            name=input("Enter DVD Name: ")
            clear()
            file1 = open('sales.txt','r')
            name=name.replace(" ","?")
            name1=name.lower()
            for i in file1:
                if name1=="main":
                    clear()
                    main()
                if name1 in i:
                    count = count -1
                    i1=i.split()
                    time,names,quantities,prices=i1[0],i1[1],i1[2],i1[3]
                    names=names.replace("?"," ")
                    names=names.title()
                    print("Name                Date             Quantity        Price")
                    print("|{0:20}|{1:15}|{2:15}|{3:5}".format(names,time,quantities,prices))
            if count==1:
                print("Name isn't present in inventory for goto main page type (main).")
            file1.close()
    if chk=="2":
        enterD=input("Enter date by means of month in numbers from (01 to 12) and date from (01 to 31) in format(date/month):\n")
        while count==1:
            enterD=input("Enter date by means of month in numbers from (01 to 12) and date from (01 to 31) in format(date/month):\n")
            clear()
            file1 = open('sales.txt','r')
            for i in file1:
                if enterD=="main":
                    clear()
                    main()
                if enterD in i:
                    count = count -1
                    i1=i.split()
                    time,names,quantities,prices=i1[0],i1[1],i1[2],i1[3]
                    names=names.replace("?"," ")
                    names=names.title()
                    print("Name                Date             Quantity        Price")
                    print("|{0:20}|{1:15}|{2:15}|{3:5}".format(names,time,quantities,prices))
                if count==1:
                    clear()
                    print("Name isn't present in inventory for goto main page type (main).")
        file1.close()
    if chk=="3":
        file1=open("sales.txt","r") 
        print("Name                 Date             Quantity        Price")
        sum=0
        for i in file1:
            i1=i.split()
            time,names,quantities,prices=i1[0],i1[1],i1[2],i1[3]
            i1[3]=int(i1[3])
            sum+=i1[3]
            names=names.replace("?"," ")
            print("|{0:20}|{1:15}|{2:15}|{3:5}".format(names,time,quantities,prices))
        print("\033[1;30;47m Total sale uptill now: ",sum)
        file1.close()
    main()
def clear():
    from IPython.display import clear_output
    clear_output()
def main():
    print("\033[1;30;47m Welcome to our DVD shop:")
    print("*"*26)
    want=(input("What You want:\nPress 1 for Update Inventory:\nPress 2 for Check Inventory:\nPress 3 for Edit Inventory:\nPress 4 for Delete Inventory:\nPress 5 for Purchase:\nPress 6 for Check Sale:\nFor Exit press 7:\n"))
    want=str(want)
    clear()
    while want!="1" and want!="2" and want!="3" and want!="4" and want!="5" and want!="6" and want!="7":
        print("\033[1;30;47m Please give valid instructions.")
        want=(input("What You want:\nPress 1 for Update Inventory:\nPress 2 for Check Inventory:\nPress 3 for Edit Inventory:\nPress 4 for Delete Inventory:\nPress 5 for Purchase:\nFor Exit press 7:\n"))
        clear()
    if want=="1":
        print("\033[1;30;47mWelcome to inventory update:")
        print("*"*24)
        inventory()
    if want=="2":
        print("\033[1;30;47m Welcome to our Stock:")
        print("*"*24)
        inventorycheck()
    if want=="3":
        print("\033[1;30;47m Welcome to edit inventory:")
        print("*"*24)
        edit()
    if want=="4":
        print("\033[1;30;47m Welcome to delete inventory:")
        print("*"*24)
        delete()
    if want=="5":
        print("\033[1;30;47m Welcome to Shop what you wanna buy:")
        print("*"*30)
        sale()
    if want=="6":
        print("\033[1;30;47m Welcome to Check Sale:")
        print("*"*24)
        checksale()
    if want=="7": 
        print("\033[1;30;47mThanks For Visiting our shop\nAllah Hafiz")
main()
# Out:
# Thanks For Visiting our shop
# Allah Hafiz
